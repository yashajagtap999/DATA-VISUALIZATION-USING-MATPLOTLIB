# %%
# types of plots:-- bar,line,hist,box,pie,scatter

# %%
#histogram:-- it is used to show spread of numerical value
import matplotlib.pyplot as plt
vegetables=["potato","tomato","onion","paneer"]
prices_in_kg=[20,50,100,95]
plt.hist(vegetables,bins=6,color="y")
# Out:
# (array([1., 0., 1., 0., 1., 1.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. ]),
#  <BarContainer object of 6 artists>)
